# %% [markdown]
# # **TravelTide Mastery Project**

# %% [markdown]
# Intro to TravelTide:
#
# E-booking startup TravelTide is a hot new player in the online travel industry. It has experienced steady growth since it was founded at the tail end of the COVID-19 pandemic (2021-04) on the strength of its data aggregation and search technology, which is best in class. Feedback from the customers has shown - and industry analysts agree - that TravelTide customers have access to the largest travel inventory in the e-booking space!
# CEO Kevin Talanick is very motivated to retain and add value to existing customers with a Marketing strategy built on a solid understanding of customer behavior to improve customer retention.
#
# Our mission as Data Analysts is two-fold:
# First, we need to check if the data supports Elena’s hypothesis about the existence of customers that would be especially interested in the perks she is proposing.
# Then, for each customer, assign a likely favorite perk.
#
# TravelTide database has four different tables.
# - users: user demographic information
# - sessions: information about individual browsing sessions (note: only sessions with at least 2 clicks are included)
# - Flights: information about purchased flights
# - hotels: information about hotel booked

# %% [markdown]
# # 1. Importing Libraries

# %%
import sqlalchemy as sa

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import date

# %%
print(sa.__version__)
print(pd.__version__)
print(np.__version__)
print(sns.__version__)
# Out:
# 2.0.41
# 2.3.0+4.g1dfc98e16a
# 2.0.2
# 0.13.2

# %% [markdown]
# # 2. Retreiving Data
# Traveltide database is accessed through sqlalchemy and all four tables are qurried and saved in dataframes using appropriate names.
# - **i- User Table**
# user demographic information
# - **ii- Sessions table** information about individual browsing sessions (note: only sessions with at least 2 clicks are included)
# - **iii- Flights Table** information about purchased flights
# - **iv- Flights Table** information about hotel booked

# %%
TravelTide_url = 'postgresql://Test:bQNxVzJL4g6u@ep-noisy-flower-846766.us-east-2.aws.neon.tech/TravelTide?sslmode=require'
engine = sa.create_engine(TravelTide_url)
connection = engine.connect().execution_options(isolation_level="AUTOCOMMIT")

# %%
#User table
query = """ select * from users """
df_users=pd.read_sql(sa.text(query),connection)

#Sessions table
query = """ select * from sessions """
df_sessions=pd.read_sql(sa.text(query),connection)

#flights table
query = """ select * from flights """
df_flights=pd.read_sql(sa.text(query),connection)

#hotels table
query = """ select * from hotels """
df_hotels=pd.read_sql(sa.text(query),connection)

print('\n',"---User table---",'\n' )
print('\n',df_users.head(), '\n')

print('\n',"---session table---",'\n' )
print(df_sessions.head(), '\n')

print('\n',"---flights table---",'\n' )
print(df_flights.head(),'\n')

print('\n',"---hotels table---",'\n' )
print(df_hotels.head(),'\n')
# Out:
#  ---User table---
#
#
#     user_id   birthdate gender  married  has_children home_country  \
# 0        0  1990-01-22      F    False         False          usa
# 1        1  2000-11-08      M    False         False          usa
# 2        2  1992-09-21      M    False         False          usa
# 3        3  1996-11-27      F    False         False          usa
# 4        4  1978-01-05      M     True          True          usa
#
#           home_city home_airport  home_airport_lat  home_airport_lon  \
# 0       minneapolis          MSP            44.880           -93.217
# 1  colorado springs          COS            38.806          -104.700
# 2          portland          PDX            45.589          -122.597
# 3           houston          IAH            29.980           -95.340
# 4          honolulu          HNL            21.316          -157.927
#
#   sign_up_date
# 0   2021-04-01
# 1   2021-04-01
# 2   2021-04-01
# 3   2021-04-01
# 4   2021-04-01
#
#
#  ---session table---
#
#                                 session_id  user_id trip_id  \
# 0  568249-36dffd440fed4eb19fbd20bc18c6191d   568249    None
# 1  568261-2edc5169f7134d4e8440dd6fe8620e88   568261    None
# 2  568263-c98f932ea6104513982a19b28d524bd4   568263    None
# 3  568267-c38d6ca1acb844c19e83819b4def9a0c   568267    None
# 4  568353-ac7031a0bd434ff7beb89f267caeb6cf   568353    None
#
#         session_start         session_end  flight_discount  hotel_discount  \
# 0 2023-03-11 15:30:00 2023-03-11 15:33:26            False           False
# 1 2023-03-11 17:51:00 2023-03-11 17:53:08            False           False
# 2 2023-03-11 08:39:00 2023-03-11 08:41:17            False           False
# 3 2023-03-11 12:09:00 2023-03-11 12:09:23            False           False
# 4 2023-03-11 20:18:00 2023-03-11 20:21:25            False           False
#
#    flight_discount_amount  hotel_discount_amount  flight_booked  hotel_booked  \
# 0                     NaN                    NaN          False         False
# 1                     NaN                    NaN          False         False
# 2                     NaN                    NaN          False         False
# 3                     NaN                    NaN          False         False
# 4                     NaN                    NaN          False         False
#
#    page_clicks  cancellation
# 0           28         False
# 1           17         False
# 2           19         False
# 3            3         False
# 4           28         False
#
#
#  ---flights table---
#
#                                    trip_id origin_airport   destination  \
# 0  178678-1a3a8cc45d3b40b9a3a648574552c671            ELP      hamilton
# 1  178781-7a0cc458b53d463f9511a24fa048c5dc            EFD  philadelphia
# 2  178884-8bfe6d90054d4b22ac3bfc7b4d252645            CLT        austin
# 3  178962-c13fdee05f18495c8fa2ad53b60f1b68            CLT        venice
# 4  178965-7311c548cc4f4f2ba084bbca4f2d3be1            LGA  jacksonville
#
#   destination_airport  seats  return_flight_booked      departure_time  \
# 0                 YHM      1                  True 2023-01-23 12:00:00
# 1                 PNE      1                  True 2023-01-22 14:00:00
# 2                 AUS      1                  True 2023-01-25 07:00:00
# 3                 VCE      2                  True 2023-06-06 08:00:00
# 4                 NCA      1                  True 2023-01-22 07:00:00
#
#           return_time  checked_bags             trip_airline  \
# 0 2023-01-24 12:00:00             0                  WestJet
# 1 2023-01-29 14:00:00             0          United Airlines
# 2 2023-01-29 07:00:00             1  Virgin Atlantic Airways
# 3 2023-06-16 08:00:00             2                  easyJet
# 4 2023-01-25 07:00:00             1                  Ryanair
#
#    destination_airport_lat  destination_airport_lon  base_fare_usd
# 0                   43.173                  -79.935         478.86
# 1                   39.872                  -75.241         408.45
# 2                   30.194                  -97.670         280.70
# 3                   45.505                   12.352        2677.30
# 4                   30.494                  -81.688         226.38
#
#
#  ---hotels table---
#
#                                    trip_id               hotel_name  nights  \
# 0  627046-f651a20b92b2429dad0c9146b6f9e328     Radisson  - new york       6
# 1  627052-5000a493958f4312a93389897eda4beb  Crowne Plaza - new york      17
# 2  627053-e568fcbdd4854130849ee3f865206d47     Hyatt - indianapolis       6
# 3  627054-41f4edf65bdb4c9a8cb5cfc98b0b5097      NH Hotel  - toronto      20
# 4  627055-c94187d1e42a471e8793d5e228c97f4e        Hilton - new york       6
#
#    rooms           check_in_time      check_out_time  hotel_per_room_usd
# 0      1 2023-03-10 11:00:00.000 2023-03-16 11:00:00                71.0
# 1      1 2023-03-06 11:00:00.000 2023-03-23 11:00:00               129.0
# 2      1 2023-03-12 10:19:29.685 2023-03-18 11:00:00               219.0
# 3      1 2023-03-06 11:00:00.000 2023-03-26 11:00:00               121.0
# 4      2 2023-03-09 10:09:06.435 2023-03-15 11:00:00                74.0

# %% [markdown]
# # 3. Merging tables
# Considering the session table as the main table, other three tables are left join one by one to make a single dataframe (df_traveltide) with all data together.

# %%
df_traveltide = pd.merge(df_sessions, df_users, on='user_id', how='left')# df_user left join on df_session
df_traveltide = pd.merge(df_traveltide, df_flights, on='trip_id', how='left')
df_traveltide = pd.merge(df_traveltide, df_hotels, on='trip_id', how='left') #df_traveltide has all four tables left join keeping session table as base table
df_traveltide.head()
# Out:
#                                 session_id  user_id trip_id  \
# 0  568249-36dffd440fed4eb19fbd20bc18c6191d   568249    None
# 1  568261-2edc5169f7134d4e8440dd6fe8620e88   568261    None
# 2  568263-c98f932ea6104513982a19b28d524bd4   568263    None
# 3  568267-c38d6ca1acb844c19e83819b4def9a0c   568267    None
# 4  568353-ac7031a0bd434ff7beb89f267caeb6cf   568353    None
#
#         session_start         session_end  flight_discount  hotel_discount  \
# 0 2023-03-11 15:30:00 2023-03-11 15:33:26            False           False
# 1 2023-03-11 17:51:00 2023-03-11 17:53:08            False           False
# 2 2023-03-11 08:39:00 2023-03-11 08:41:17            False           False
# 3 2023-03-11 12:09:00 2023-03-11 12:09:23            False           False
# 4 2023-03-11 20:18:00 2023-03-11 20:21:25            False           False
#
#    flight_discount_amount  hotel_discount_amount  flight_booked  ...  \
# 0                     NaN                    NaN          False  ...
# 1                     NaN                    NaN          False  ...
# 2                     NaN                    NaN          False  ...
# 3                     NaN                    NaN          False  ...
# 4                     NaN                    NaN          False  ...
#
#    trip_airline  destination_airport_lat  destination_airport_lon  \
# 0           NaN                      NaN                      NaN
# 1           NaN                      NaN                      NaN
# 2           NaN                      NaN                      NaN
# 3           NaN                      NaN                      NaN
# 4           NaN                      NaN                      NaN
#
#   base_fare_usd hotel_name  nights  rooms check_in_time check_out_time  \
# 0           NaN        NaN     NaN    NaN           NaT            NaT
# 1           NaN        NaN     NaN    NaN           NaT            NaT
# 2           NaN        NaN     NaN    NaN           NaT            NaT
# 3           NaN        NaN     NaN    NaN           NaT            NaT
# 4           NaN        NaN     NaN    NaN           NaT            NaT
#
#   hotel_per_room_usd
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# # Basic Data exploration
# An over view of collected data shows, Database provides us a dataframe of 5408063 rows and 41 feature columns. Data enteries are collected almost for two years, spaning the time frame  2021-04-01 to 2023-07-29. 5408063 unique sessions are there out of which only 2335845 sessions are dealing with trip_ids and resulting in 2245175 unique trips. Traveltide has 1020926 unique users.

# %%
print('\n',df_traveltide.shape,'\n',"------------",'\n')
df_traveltide['user_id'] = df_traveltide['user_id'].astype(object)
print('\n',df_traveltide.info(),'\n'"------------",'\n')
print('\n',df_traveltide.describe().T,'\n',"------------",'\n')
print('\n',df_traveltide.describe(include= 'object').T,'\n',"------------",'\n')
# Out:
#  (5408063, 41)
#  ------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5408063 entries, 0 to 5408062
# Data columns (total 41 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   session_id               object
#  1   user_id                  object
#  2   trip_id                  object
#  3   session_start            datetime64[ns]
#  4   session_end              datetime64[ns]
#  5   flight_discount          bool
#  6   hotel_discount           bool
#  7   flight_discount_amount   float64
#  8   hotel_discount_amount    float64
#  9   flight_booked            bool
#  10  hotel_booked             bool
#  11  page_clicks              int64
#  12  cancellation             bool
#  13  birthdate                object
#  14  gender                   object
#  15  married                  bool
#  16  has_children             bool
#  17  home_country             object
#  18  home_city                object
#  19  home_airport             object
#  20  home_airport_lat         float64
#  21  home_airport_lon         float64
#  22  sign_up_date             object
#  23  origin_airport           object
#  24  destination              object
#  25  destination_airport      object
#  26  seats                    float64
#  27  return_flight_booked     object
#  28  departure_time           datetime64[ns]
#  29  return_time              datetime64[ns]
#  30  checked_bags             float64
#  31  trip_airline             object
#  32  destination_airport_lat  float64
#  33  destination_airport_lon  float64
#  34  base_fare_usd            float64
#  35  hotel_name               object
#  36  nights                   float64
#  37  rooms                    float64
#  38  check_in_time            datetime64[ns]
#  39  check_out_time           datetime64[ns]
#  40  hotel_per_room_usd       float64
# dtypes: bool(7), datetime64[ns](6), float64(12), int64(1), object(15)
# memory usage: 1.4+ GB
#
#  None
# ------------
#
#
#                               count                           mean  \
# session_start              5408063  2022-12-12 02:37:01.270521856
# session_end                5408063  2022-12-12 02:40:35.487092224
# flight_discount_amount    885796.0                       0.139765
# hotel_discount_amount     691380.0                        0.11095
# page_clicks              5408063.0                      18.766031
# home_airport_lat         5408063.0                      38.552075
# home_airport_lon         5408063.0                     -93.917546
# seats                    1990382.0                       1.277859
# departure_time             1990382  2023-01-14 10:51:34.890327296
# return_time                1898156  2023-01-20 03:26:25.106384896
# checked_bags             1990382.0                         0.6248
# destination_airport_lat  1990382.0                       37.87522
# destination_airport_lon  1990382.0                     -80.173799
# base_fare_usd            1990382.0                     714.099763
# nights                   1962920.0                       4.393498
# rooms                    1962920.0                       1.189723
# check_in_time              1962920  2022-12-30 15:39:33.355753984
# check_out_time             1962920  2023-01-04 12:24:46.935788032
# hotel_per_room_usd       1962920.0                     177.309672
#
#                                                 min  \
# session_start                   2021-04-01 00:42:00
# session_end                     2021-04-01 00:43:40
# flight_discount_amount                         0.05
# hotel_discount_amount                          0.05
# page_clicks                                     0.0
# home_airport_lat                             21.316
# home_airport_lon                           -157.927
# seats                                           0.0
# departure_time                  2021-04-06 07:00:00
# return_time                     2021-04-09 07:00:00
# checked_bags                                    0.0
# destination_airport_lat                     -37.008
# destination_airport_lon                    -157.927
# base_fare_usd                                   0.0
# nights                                         -2.0
# rooms                                           0.0
# check_in_time            2021-04-06 10:40:44.175000
# check_out_time                  2021-04-08 11:00:00
# hotel_per_room_usd                              8.0
#
#                                                    25%  \
# session_start                      2022-08-30 12:52:00
# session_end                 2022-08-30 12:57:44.500000
# flight_discount_amount                             0.1
# hotel_discount_amount                             0.05
# page_clicks                                        7.0
# home_airport_lat                                33.942
# home_airport_lon                              -112.008
# seats                                              1.0
# departure_time                     2022-10-05 07:00:00
# return_time                        2022-10-10 12:00:00
# checked_bags                                       0.0
# destination_airport_lat                         33.535
# destination_airport_lon                       -112.383
# base_fare_usd                                   207.01
# nights                                             1.0
# rooms                                              1.0
# check_in_time            2022-09-19 10:48:04.736250112
# check_out_time                     2022-09-24 11:00:00
# hotel_per_room_usd                                99.0
#
#                                                    50%                  75%  \
# session_start                      2023-01-28 09:13:00  2023-04-22 20:33:00
# session_end                        2023-01-28 09:16:45  2023-04-22 20:37:01
# flight_discount_amount                             0.1                  0.2
# hotel_discount_amount                              0.1                 0.15
# page_clicks                                       15.0                 23.0
# home_airport_lat                                39.297               42.276
# home_airport_lon                               -89.977              -77.456
# seats                                              1.0                  1.0
# departure_time                     2023-02-18 12:00:00  2023-05-23 10:00:00
# return_time                        2023-02-23 10:00:00  2023-05-28 15:00:00
# checked_bags                                       1.0                  1.0
# destination_airport_lat                         39.858               42.409
# destination_airport_lon                        -87.752              -73.779
# base_fare_usd                                   405.36               660.51
# nights                                             3.0                  6.0
# rooms                                              1.0                  1.0
# check_in_time            2023-02-10 13:30:26.122500096  2023-05-10 11:00:00
# check_out_time                     2023-02-15 11:00:00  2023-05-14 11:00:00
# hotel_per_room_usd                               148.0                222.0
#
#                                                 max          std
# session_start                   2023-07-28 23:57:55          NaN
# session_end                     2023-07-29 01:57:55          NaN
# flight_discount_amount                         0.85     0.085191
# hotel_discount_amount                          0.65     0.062021
# page_clicks                                  2421.0    22.180703
# home_airport_lat                             61.251     6.119254
# home_airport_lon                            -63.499    18.099381
# seats                                          12.0     0.681713
# departure_time                  2024-07-19 22:00:00          NaN
# return_time                     2024-08-19 18:00:00          NaN
# checked_bags                                   13.0     0.746329
# destination_airport_lat                      58.789     8.605096
# destination_airport_lon                     174.792    49.485013
# base_fare_usd                              29987.92  1233.925055
# nights                                        107.0     4.573541
# rooms                                           6.0     0.489183
# check_in_time            2024-07-20 17:08:06.585000          NaN
# check_out_time                  2024-08-13 11:00:00          NaN
# hotel_per_room_usd                           2377.0   117.197108
#  ------------
#
#
#                          count   unique  \
# session_id            5408063  5408063
# user_id               5408063  1020926
# trip_id               2335845  2245175
# birthdate             5408063    22581
# gender                5408063        3
# home_country          5408063        2
# home_city             5408063      105
# home_airport          5408063      159
# sign_up_date          5408063      831
# origin_airport        1990382      159
# destination           1990382      140
# destination_airport   1990382      219
# return_flight_booked  1990382        2
# trip_airline          1990382      355
# hotel_name            1962920     2798
#
#                                                           top     freq
# session_id            568249-36dffd440fed4eb19fbd20bc18c6191d        1
# user_id                                                 36751       17
# trip_id               529807-9c2d9ea6153040eb99a078000859b1d3        2
# birthdate                                          2006-09-26      879
# gender                                                      M  2722001
# home_country                                              usa  4493643
# home_city                                            new york   644028
# home_airport                                              JFK   322072
# sign_up_date                                       2022-12-17    14013
# origin_airport                                            JFK   124648
# destination                                          new york   262144
# destination_airport                                       LGA   131191
# return_flight_booked                                     True  1898156
# trip_airline                                  Delta Air Lines   280501
# hotel_name                               Radisson  - new york    14247
#  ------------

# %% [markdown]
# # 3. Filtering data and Cohort Selection
#  To Work on chronologicaly recent data, records after 2023-01-04 has been filtered, Also, user with more than 7 sessions have been selected considering them enough onsite active  to better understand the customer behavior. After applying these two filters a cohort is selected and named df_filtered_cohort, for further analysis.

# %%
# taking rows after 2023-01-04, retreiving most recent data
df_traveltide= df_traveltide[(df_traveltide['session_start'] >= '2023-01-04')]
print(f"{df_traveltide.shape} are the rows and column of df_traveltide after date filter applied.")

# taking users which are active enough to do atleast 8 sessions, to have enough data to work on
session_counts = df_traveltide.groupby('user_id')['session_id'].count()
filtered_users = session_counts[session_counts > 7].index
session_counts = df_traveltide.groupby('user_id')['session_id'].count()
df_filtered_cohort = df_traveltide[df_traveltide['user_id'].isin(filtered_users)]
df_filtered_cohort.reset_index(drop=True, inplace=True)
print(f"{df_filtered_cohort.shape} are the rows and column of df_traveltide after date filter and session filter applied.")


#after applying the filters for date (2023-01-04)and least number of sessions per user(>7)
df_filtered_cohort
# Out:
# (3102851, 41) are the rows and column of df_traveltide after date filter applied.
# (49211, 41) are the rows and column of df_traveltide after date filter and session filter applied.
#                                     session_id user_id  \
# 0      568486-9eebc8f1663c4ba0a0e4063a9baa2416  568486
# 1      568970-0e40b0e835344789b2f5f04f727ae26c  568970
# 2      569150-5535ba3bf6364c63acc5d3afb6eeea23  569150
# 3      569792-a6917b28a30543fdb54bc1111bab7434  569792
# 4      570242-9b67a8f30cfc45a2a19acc0cc701d215  570242
# ...                                        ...     ...
# 49206  566762-d577ecf656fd41018c8e6e5270a7bbf2  566762
# 49207  566815-1b6170f8e3244225af1f51ebc7738df2  566815
# 49208  566964-c0345bf9713e46ffa7ef1087b3e8b6c7  566964
# 49209  567643-9b68cfcab1784f37b245139db8319164  567643
# 49210  568167-ab28cb84085e4682889831de3f128d3b  568167
#
#                                        trip_id       session_start  \
# 0                                         None 2023-03-11 18:24:00
# 1                                         None 2023-03-11 14:26:00
# 2                                         None 2023-03-11 14:04:00
# 3      569792-69cf69a17fd64dcc8fb0486659b74c55 2023-03-11 10:20:00
# 4                                         None 2023-03-11 02:15:00
# ...                                        ...                 ...
# 49206  566762-0fe29be75b26415ebe9c587d370782dd 2023-03-11 16:45:00
# 49207  566815-7e38244b926f4e8b864ede27bdecd3f7 2023-03-11 09:11:00
# 49208  566964-4a1601e6e0594bc6a9d464f902d3233b 2023-03-11 13:05:00
# 49209                                     None 2023-03-11 21:05:00
# 49210                                     None 2023-03-11 17:45:00
#
#               session_end  flight_discount  hotel_discount  \
# 0     2023-03-11 18:24:37            False           False
# 1     2023-03-11 14:27:00            False            True
# 2     2023-03-11 14:04:46            False           False
# 3     2023-03-11 10:22:12            False           False
# 4     2023-03-11 02:16:23            False            True
# ...                   ...              ...             ...
# 49206 2023-03-11 16:47:24             True           False
# 49207 2023-03-11 09:13:08            False           False
# 49208 2023-03-11 13:07:42            False           False
# 49209 2023-03-11 21:06:29             True           False
# 49210 2023-03-11 17:48:01            False           False
#
#        flight_discount_amount  hotel_discount_amount  flight_booked  ...  \
# 0                         NaN                    NaN          False  ...
# 1                         NaN                    0.1          False  ...
# 2                         NaN                    NaN          False  ...
# 3                         NaN                    NaN           True  ...
# 4                         NaN                    0.1          False  ...
# ...                       ...                    ...            ...  ...
# 49206                    0.15                    NaN           True  ...
# 49207                     NaN                    NaN           True  ...
# 49208                     NaN                    NaN           True  ...
# 49209                    0.10                    NaN          False  ...
# 49210                     NaN                    NaN          False  ...
#
#             trip_airline  destination_airport_lat  destination_airport_lon  \
# 0                    NaN                      NaN                      NaN
# 1                    NaN                      NaN                      NaN
# 2                    NaN                      NaN                      NaN
# 3                Ryanair                   32.820                  -97.362
# 4                    NaN                      NaN                      NaN
# ...                  ...                      ...                      ...
# 49206    AirTran Airways                   40.640                  -73.779
# 49207  American Airlines                   33.535                 -112.383
# 49208  American Airlines                   43.862                  -79.370
# 49209                NaN                      NaN                      NaN
# 49210                NaN                      NaN                      NaN
#
#       base_fare_usd               hotel_name  nights  rooms  \
# 0               NaN                      NaN     NaN    NaN
# 1               NaN                      NaN     NaN    NaN
# 2               NaN                      NaN     NaN    NaN
# 3            266.97     Conrad  - fort worth     2.0    4.0
# 4               NaN                      NaN     NaN    NaN
# ...             ...                      ...     ...    ...
# 49206        321.34  Aman Resorts - new york     2.0    1.0
# 49207        695.28   Four Seasons - phoenix     2.0    1.0
# 49208        114.17          Accor - toronto     0.0    1.0
# 49209           NaN                      NaN     NaN    NaN
# 49210           NaN                      NaN     NaN    NaN
#
#                 check_in_time      check_out_time hotel_per_room_usd
# 0                         NaT                 NaT                NaN
# 1                         NaT                 NaT                NaN
# 2                         NaT                 NaT                NaN
# 3     2023-03-17 10:29:56.130 2023-03-19 11:00:00              225.0
# 4                         NaT                 NaT                NaN
# ...                       ...                 ...                ...
# 49206 2023-03-18 11:08:05.865 2023-03-20 11:00:00              153.0
# 49207 2023-03-19 14:20:46.995 2023-03-22 11:00:00              548.0
# 49208 2023-03-16 12:43:43.365 2023-03-17 11:00:00               92.0
# 49209                     NaT                 NaT                NaN
# 49210                     NaT                 NaT                NaN
#
# [49211 rows x 41 columns]

# %% [markdown]
# # CSV created
# Filtered rows are saved in df_filteref_cohort, a copy of this is made and further CSV created to work on next steps in pipline.

# %%
df_cohort = df_filtered_cohort.copy()
df_filtered_cohort.to_csv('Data/df_cohort.csv', index=False)
df_cohort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49211 entries, 0 to 49210
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   session_id               49211 non-null  object
#  1   user_id                  49211 non-null  object
#  2   trip_id                  16702 non-null  object
#  3   session_start            49211 non-null  datetime64[ns]
#  4   session_end              49211 non-null  datetime64[ns]
#  5   flight_discount          49211 non-null  bool
#  6   hotel_discount           49211 non-null  bool
#  7   flight_discount_amount   8282 non-null   float64
#  8   hotel_discount_amount    6205 non-null   float64
#  9   flight_booked            49211 non-null  bool
#  10  hotel_booked             49211 non-null  bool
#  11  page_clicks              49211 non-null  int64
#  12  cancellation             49211 non-null  bool
#  13  birthdate                49211 non-null  object
#  14  gender                   49211 non-null  object
#  15  married                  49211 non-null  bool
#  16  has_children             49211 non-null  bool
#  17  home_country             49211 non-null  object
#  18  home_city                49211 non-null  object
#  19  home_airport             49211 non-null  object
#  20  home_airport_lat         49211 non-null  float64
#  21  home_airport_lon         49211 non-null  float64
#  22  sign_up_date             49211 non-null  object
#  23  origin_airport           14270 non-null  object
#  24  destination              14270 non-null  object
#  25  destination_airport      14270 non-null  object
#  26  seats                    14270 non-null  float64
#  27  return_flight_booked     14270 non-null  object
#  28  departure_time           14270 non-null  datetime64[ns]
#  29  return_time              13652 non-null  datetime64[ns]
#  30  checked_bags             14270 non-null  float64
#  31  trip_airline             14270 non-null  object
#  32  destination_airport_lat  14270 non-null  float64
#  33  destination_airport_lon  14270 non-null  float64
#  34  base_fare_usd            14270 non-null  float64
#  35  hotel_name               14726 non-null  object
#  36  nights                   14726 non-null  float64
#  37  rooms                    14726 non-null  float64
#  38  check_in_time            14726 non-null  datetime64[ns]
#  39  check_out_time           14726 non-null  datetime64[ns]
#  40  hotel_per_room_usd       14726 non-null  float64
# dtypes: bool(7), datetime64[ns](6), float64(12), int64(1), object(15)
# memory usage: 13.1+ MB

# %% [markdown]
# ## Fixing detypes of columns
# Some of features are not in appropriate detype, for these coloumn it is fixed accordingly.

# %%
df_cohort['temp'] = -1

df_cohort['temp'] = np.where(df_cohort['return_flight_booked'] == True, 1, df_cohort['temp'])
df_cohort['temp'] = np.where(df_cohort['return_flight_booked'] == False, 0, df_cohort['temp'])
df_cohort['temp'].replace(-1, np.nan, inplace=True)
#df_cohort['temp'].value_counts()
# Out:
# /var/folders/gq/3d_53n2d05n2_n592s2dd_mr0000gn/T/ipykernel_95485/3932483766.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cohort['temp'].replace(-1, np.nan, inplace=True)

# %%
df_cohort['user_id'] = df_cohort['user_id'].astype(object)
df_cohort['birthdate'] = pd.to_datetime(df_cohort['birthdate'])
df_cohort['sign_up_date'] = pd.to_datetime(df_cohort['sign_up_date'])
df_cohort['return_flight_booked'] = df_cohort['temp']
df_cohort.drop(columns=['temp'], inplace=True)
df_cohort.info()
#df_cohort['return_flight_booked'] = df_cohort['return_flight_booked'].astype(bool)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49211 entries, 0 to 49210
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   session_id               49211 non-null  object
#  1   user_id                  49211 non-null  object
#  2   trip_id                  16702 non-null  object
#  3   session_start            49211 non-null  datetime64[ns]
#  4   session_end              49211 non-null  datetime64[ns]
#  5   flight_discount          49211 non-null  bool
#  6   hotel_discount           49211 non-null  bool
#  7   flight_discount_amount   8282 non-null   float64
#  8   hotel_discount_amount    6205 non-null   float64
#  9   flight_booked            49211 non-null  bool
#  10  hotel_booked             49211 non-null  bool
#  11  page_clicks              49211 non-null  int64
#  12  cancellation             49211 non-null  bool
#  13  birthdate                49211 non-null  datetime64[ns]
#  14  gender                   49211 non-null  object
#  15  married                  49211 non-null  bool
#  16  has_children             49211 non-null  bool
#  17  home_country             49211 non-null  object
#  18  home_city                49211 non-null  object
#  19  home_airport             49211 non-null  object
#  20  home_airport_lat         49211 non-null  float64
#  21  home_airport_lon         49211 non-null  float64
#  22  sign_up_date             49211 non-null  datetime64[ns]
#  23  origin_airport           14270 non-null  object
#  24  destination              14270 non-null  object
#  25  destination_airport      14270 non-null  object
#  26  seats                    14270 non-null  float64
#  27  return_flight_booked     14270 non-null  float64
#  28  departure_time           14270 non-null  datetime64[ns]
#  29  return_time              13652 non-null  datetime64[ns]
#  30  checked_bags             14270 non-null  float64
#  31  trip_airline             14270 non-null  object
#  32  destination_airport_lat  14270 non-null  float64
#  33  destination_airport_lon  14270 non-null  float64
#  34  base_fare_usd            14270 non-null  float64
#  35  hotel_name               14726 non-null  object
#  36  nights                   14726 non-null  float64
#  37  rooms                    14726 non-null  float64
#  38  check_in_time            14726 non-null  datetime64[ns]
#  39  check_out_time           14726 non-null  datetime64[ns]
#  40  hotel_per_room_usd       14726 non-null  float64
# dtypes: bool(7), datetime64[ns](8), float64(13), int64(1), object(12)
# memory usage: 13.1+ MB

# %%
# Test saving to parquet file

# Save to Parquet format
df_cohort.to_parquet('df_cohort.parquet')

# Load from Parquet format
loaded_df = pd.read_parquet('df_cohort.parquet')

# Verify the dtypes
print("Original DataFrame dtypes:\n", df_cohort.dtypes)
print("\nLoaded DataFrame dtypes:\n", loaded_df.dtypes)
print("\nAre dtypes the same?", (df_cohort.dtypes == loaded_df.dtypes).all())
# Out:
# Original DataFrame dtypes:
#  session_id                         object
# user_id                            object
# trip_id                            object
# session_start              datetime64[ns]
# session_end                datetime64[ns]
# flight_discount                      bool
# hotel_discount                       bool
# flight_discount_amount            float64
# hotel_discount_amount             float64
# flight_booked                        bool
# hotel_booked                         bool
# page_clicks                         int64
# cancellation                         bool
# birthdate                  datetime64[ns]
# gender                             object
# married                              bool
# has_children                         bool
# home_country                       object
# home_city                          object
# home_airport                       object
# home_airport_lat                  float64
# home_airport_lon                  float64
# sign_up_date               datetime64[ns]
# origin_airport                     object
# destination                        object
# destination_airport                object
# seats                             float64
# return_flight_booked              float64
# departure_time             datetime64[ns]
# return_time                datetime64[ns]
# checked_bags                      float64
# trip_airline                       object
# destination_airport_lat           float64
# destination_airport_lon           float64
# base_fare_usd                     float64
# hotel_name                         object
# nights                            float64
# rooms                             float64
# check_in_time              datetime64[ns]
# check_out_time             datetime64[ns]
# hotel_per_room_usd                float64
# dtype: object
#
# Loaded DataFrame dtypes:
#  session_id                         object
# user_id                             int64
# trip_id                            object
# session_start              datetime64[ns]
# session_end                datetime64[ns]
# flight_discount                      bool
# hotel_discount                       bool
# flight_discount_amount            float64
# hotel_discount_amount             float64
# flight_booked                        bool
# hotel_booked                         bool
# page_clicks                         int64
# cancellation                         bool
# birthdate                  datetime64[ns]
# gender                             object
# married                              bool
# has_children                         bool
# home_country                       object
# home_city                          object
# home_airport                       object
# home_airport_lat                  float64
# home_airport_lon                  float64
# sign_up_date               datetime64[ns]
# origin_airport                     object
# destination                        object
# destination_airport                object
# seats                             float64
# return_flight_booked              float64
# departure_time             datetime64[ns]
# return_time                datetime64[ns]
# checked_bags                      float64
# trip_airline                       object
# destination_airport_lat           float64
# destination_airport_lon           float64
# base_fare_usd                     float64
# hotel_name                         object
# nights                            float64
# rooms                             float64
# check_in_time              datetime64[ns]
# check_out_time             datetime64[ns]
# hotel_per_room_usd                float64
# dtype: object
#
# Are dtypes the same? False

# %%
res = pd.DataFrame({'original': df_cohort.dtypes, 'loaded': loaded_df.dtypes})
res['res'] = res['original'] == res['loaded']
res
# Out:
#                                original          loaded    res
# session_id                       object          object   True
# user_id                          object           int64  False
# trip_id                          object          object   True
# session_start            datetime64[ns]  datetime64[ns]   True
# session_end              datetime64[ns]  datetime64[ns]   True
# flight_discount                    bool            bool   True
# hotel_discount                     bool            bool   True
# flight_discount_amount          float64         float64   True
# hotel_discount_amount           float64         float64   True
# flight_booked                      bool            bool   True
# hotel_booked                       bool            bool   True
# page_clicks                       int64           int64   True
# cancellation                       bool            bool   True
# birthdate                datetime64[ns]  datetime64[ns]   True
# gender                           object          object   True
# married                            bool            bool   True
# has_children                       bool            bool   True
# home_country                     object          object   True
# home_city                        object          object   True
# home_airport                     object          object   True
# home_airport_lat                float64         float64   True
# home_airport_lon                float64         float64   True
# sign_up_date             datetime64[ns]  datetime64[ns]   True
# origin_airport                   object          object   True
# destination                      object          object   True
# destination_airport              object          object   True
# seats                           float64         float64   True
# return_flight_booked            float64         float64   True
# departure_time           datetime64[ns]  datetime64[ns]   True
# return_time              datetime64[ns]  datetime64[ns]   True
# checked_bags                    float64         float64   True
# trip_airline                     object          object   True
# destination_airport_lat         float64         float64   True
# destination_airport_lon         float64         float64   True
# base_fare_usd                   float64         float64   True
# hotel_name                       object          object   True
# nights                          float64         float64   True
# rooms                           float64         float64   True
# check_in_time            datetime64[ns]  datetime64[ns]   True
# check_out_time           datetime64[ns]  datetime64[ns]   True
# hotel_per_room_usd              float64         float64   True
